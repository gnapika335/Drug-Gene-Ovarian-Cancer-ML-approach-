# %%
# !pip install pandas numpy scikit-learn matplotlib seaborn networkx shap biopython xgboost lightgbm rdkit
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 35.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.1/36.1 MB 50.8 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import numpy as np
import sklearn
import xgboost as xgb
import lightgbm as lgb
from rdkit import Chem
from Bio import SeqIO # Corrected import for Biopython
import networkx as nx
import shap
import matplotlib.pyplot as plt
import seaborn as sns
